# %%
print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
# X will be the data matrix, y will be the regression target
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
X = X[:, 2]
print(X)
X = X.reshape((-1,1))
print(X)
# Out:
# [ 0.06169621 -0.05147406  0.04445121 -0.01159501 -0.03638469 -0.04069594
#  -0.04716281 -0.00189471  0.06169621  0.03906215 -0.08380842  0.01750591
#  -0.02884001 -0.00189471 -0.02560657 -0.01806189  0.04229559  0.01211685
#  -0.0105172  -0.01806189 -0.05686312 -0.02237314 -0.00405033  0.06061839
#   0.03582872 -0.01267283 -0.07734155  0.05954058 -0.02129532 -0.00620595
#   0.04445121 -0.06548562  0.12528712 -0.05039625 -0.06332999 -0.03099563
#   0.02289497  0.01103904  0.07139652  0.01427248 -0.00836158 -0.06764124
#  -0.0105172  -0.02345095  0.06816308 -0.03530688 -0.01159501 -0.0730303
#  -0.04177375  0.01427248 -0.00728377  0.0164281  -0.00943939 -0.01590626
#   0.0250506  -0.04931844  0.04121778 -0.06332999 -0.06440781 -0.02560657
#  -0.00405033  0.00457217 -0.00728377 -0.0374625  -0.02560657 -0.02452876
#  -0.01806189 -0.01482845 -0.02991782 -0.046085   -0.06979687  0.03367309
#  -0.00405033 -0.02021751  0.00241654 -0.03099563  0.02828403 -0.03638469
# ...

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)
# train the model
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# create a prediction using the test data 
y_pred = model.predict(X_test)

# %%
# plot the data
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()

# %% [markdown]
# Now I'm going to plot a different variable from this dataset.

# %%
# X will be the data matrix, y will be the regression target
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])

X = X[:, 3]
print(X)
X = X.reshape((-1,1))
print(X)

# split into train and test sets
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)
# train the model
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# create a prediction using the test data 
y_pred = model.predict(X_test)

# plot the data
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]
# [ 2.18723855e-02 -2.63275281e-02 -5.67042229e-03 -3.66560811e-02
#   2.18723855e-02 -1.94418262e-02 -1.59989752e-02  6.66294482e-02
#  -4.00989321e-02 -3.32132301e-02  8.10098161e-03 -3.32132301e-02
#  -9.11327327e-03  8.10098161e-03 -1.25561242e-02  8.04008521e-02
#   4.94151933e-02  5.63008953e-02 -3.66560811e-02 -4.00989321e-02
#  -4.35417830e-02  1.21527966e-03 -9.11327327e-03  3.10647976e-02
#  -2.28846772e-02 -4.00989321e-02 -2.63275281e-02 -4.00989321e-02
#  -7.45274418e-02  6.31865972e-02 -1.94418262e-02 -8.14131438e-02
#   2.87580875e-02 -2.22757132e-03 -5.73131869e-02 -4.92913442e-02
#   5.28580443e-02 -5.73131869e-02  9.76151070e-02 -7.45274418e-02
#   2.18723855e-02 -1.08955952e-01 -1.48628344e-02 -7.10845908e-02
#   8.10098161e-03  3.22009384e-02 -3.32132301e-02 -5.73131869e-02
# ...
